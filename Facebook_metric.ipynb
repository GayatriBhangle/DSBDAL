# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset_facebook.csv", sep=";")

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.isna().sum().sum()
# Out:
# 6

# %%
data['Paid'].fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data['like'].fillna(0, inplace=True)

# %%
data['share'].fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
photo_subset = data[data['Type'] == 'Photo']
status_subset = data[data['Type'] == 'Status']
link_subset = data[data['Type'] == 'Link']
video_subset = data[data['Type'] =='Video']

# %%
video_subset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
merged_subset = pd.concat([status_subset, photo_subset], ignore_index =True)

# %%
merged_subset
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Status         2          12             3         10
# 1              139441  Status         2          12             1          9
# 2              139441  Status         2          12             7          3
# 3              139441  Status         2          12             5         10
# 4              138414  Status         2          12             3         10
# ..                ...     ...       ...         ...           ...        ...
# 466             85093   Photo         3           1             7          2
# 467             81370   Photo         2           1             5          8
# 468             81370   Photo         1           1             5          2
# 469             81370   Photo         3           1             4         11
# 470             81370   Photo         2           1             4          4
#
# ...

# %%
sorted_data = data.sort_values(by='Page total likes')

# %%
sorted_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
trnasposed_data = data.T

# %%
trnasposed_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
# Assuming you want to melt all columns except 'Type':
melted_data = pd.melt(data, id_vars = 'Type', var_name= 'Metric', value_name = 'Value')

# %%
melted_data
# Out:
#         Type              Metric     Value
# 0      Photo    Page total likes  139441.0
# 1     Status    Page total likes  139441.0
# 2      Photo    Page total likes  139441.0
# 3      Photo    Page total likes  139441.0
# 4      Photo    Page total likes  139441.0
# ...      ...                 ...       ...
# 8995   Photo  Total Interactions      84.0
# 8996   Photo  Total Interactions      75.0
# 8997   Photo  Total Interactions     115.0
# 8998   Photo  Total Interactions     136.0
# 8999   Photo  Total Interactions     119.0
#
# [9000 rows x 3 columns]

# %%
rm_duplicate = melted_data.drop_duplicates(subset=['Type', 'Metric'])

# %%
rm_duplicate
# Out:
#         Type              Metric     Value
# 0      Photo    Page total likes  139441.0
# 1     Status    Page total likes  139441.0
# 22      Link    Page total likes  138414.0
# 29     Video    Page total likes  138895.0
# 500    Photo            Category       2.0
# ...      ...                 ...       ...
# 8029   Video               share      13.0
# 8500   Photo  Total Interactions     100.0
# 8501  Status  Total Interactions     164.0
# 8522    Link  Total Interactions      18.0
# 8529   Video  Total Interactions     174.0
#
# [72 rows x 3 columns]

# %%
casted_data = rm_duplicate.pivot(index='Type', columns='Metric', values='Value')

# %%
aggregated_data = melted_data.groupby(['Type', 'Metric']).mean().reset_index()

# %%
casted_data = aggregated_data.pivot(index='Type', columns='Metric',values='Value')

# %%
casted_data
# Out:
# Metric  Category  Lifetime Engaged Users  \
# Type
# Link    1.136364              342.818182
# Photo   1.917840              818.946009
# Status  2.022222             2040.222222
# Video   1.000000             1707.000000
#
# Metric  Lifetime People who have liked your Page and engaged with your post  \
# Type
# Link                                           210.545455
# Photo                                          507.305164
# Status                                        1719.844444
# Video                                          979.428571
#
# Metric  Lifetime Post Consumers  Lifetime Post Consumptions  \
# Type
# Link                 292.681818                  374.090909
# Photo                690.431925                 1299.025822
# Status              1949.555556                 2838.866667
# Video               1584.714286                 2600.142857
#
# Metric  Lifetime Post Impressions by people who have liked your Page  \
# Type
# ...
